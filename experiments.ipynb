# %%
import numpy as np
from PIL import Image
from NNfeatures import NNfeatures
import cv2
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import argparse
from sklearn.svm import SVR
import torch
from TestTracker import TestTracker

# %% [markdown]
# The code are edied based on the got10k tool kit documentation. You can find their orignial repo here: https://github.com/got-10k/toolkit#installation

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from got10k.trackers import Tracker
from got10k.experiments import ExperimentGOT10k

# %%
# ... tracker definition ...

# instantiate a tracker
hog_linear_tracker = TestTracker(model_name='hog', kernel='linear', device=device, name='hog-linear-noncontinuous', continuous=False)

# setup experiment (validation subset)
experiment = ExperimentGOT10k(
    root_dir='data/GOT-10k',    # GOT-10k's root directory
    subset='val',               # 'train' | 'val' | 'test'
    result_dir='./results',       # where to store tracking results
    report_dir='./reports'        # where to store evaluation reports
)
experiment.run(tracker, visualize=False)
# Out:
# Running tracker ResNet18-linear-noncontinuous on GOT-10k...
# --Sequence 1/180: GOT-10k_Val_000001
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-linear-noncontinuous\GOT-10k_Val_000001\GOT-10k_Val_000001_001.txt
# --Sequence 2/180: GOT-10k_Val_000002
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-linear-noncontinuous\GOT-10k_Val_000002\GOT-10k_Val_000002_001.txt
# --Sequence 3/180: GOT-10k_Val_000003
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-linear-noncontinuous\GOT-10k_Val_000003\GOT-10k_Val_000003_001.txt
# --Sequence 4/180: GOT-10k_Val_000004
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-linear-noncontinuous\GOT-10k_Val_000004\GOT-10k_Val_000004_001.txt
# --Sequence 5/180: GOT-10k_Val_000005
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-linear-noncontinuous\GOT-10k_Val_000005\GOT-10k_Val_000005_001.txt
# --Sequence 6/180: GOT-10k_Val_000006
#  Repetition: 1
# ...

# %%
experiment.report(['hog-linear-noncontinuous'])
# Out:
# Evaluating hog-linear-noncontinuous
# Saving success plots to ./reports\GOT-10k\hog-linear-noncontinuous\success_plot.png
# {'hog-linear-noncontinuous': {'overall': {'ao': 0.17701178756009278,
#    'sr': 0.17120323170145235,
#    'speed_fps': 5.997065215568012,
#    'succ_curve': [0.515773780898336,
#     0.4438299509473887,
#     0.42055400596325865,
#     0.40098105222660385,
#     0.38448590939694144,
#     0.37203039338270655,
#     0.3600557853226892,
#     0.3489468115802635,
#     0.34072328556314324,
#     0.3329325767048187,
#     0.32605559295950753,
#     0.3200923343272098,
#     0.31393671251322497,
#     0.30681927479080506,
#     0.29931711070501105,
#     0.29412330479946136,
#     0.2899394055977686,
#     0.28580359719149756,
#     0.2813311532172742,
#     0.2768106184476291,
#     0.2715206309512359,
#     0.2675771857266519,
#     0.26228719823025876,
#     0.2578147542560354,
#     0.252765220736751,
#     0.24930268346638454,
#     0.24507069346927,
# ...

# %%
# ... tracker definition ...

# instantiate a tracker
res_linear_tracker = TestTracker(model_name='resnet18', kernel='linear', device=device, name='ResNet18-linear-noncontinuous', continuous=False)

# setup experiment (validation subset)
experiment = ExperimentGOT10k(
    root_dir='data/GOT-10k',    # GOT-10k's root directory
    subset='val',               # 'train' | 'val' | 'test'
    result_dir='./results',       # where to store tracking results
    report_dir='./reports'        # where to store evaluation reports
)
experiment.run(res_linear_tracker, visualize=False)
# Out:
# Running tracker ResNet18-linear-noncontinuous on GOT-10k...
# --Sequence 1/180: GOT-10k_Val_000001
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000001
# --Sequence 2/180: GOT-10k_Val_000002
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000002
# --Sequence 3/180: GOT-10k_Val_000003
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000003
# --Sequence 4/180: GOT-10k_Val_000004
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000004
# --Sequence 5/180: GOT-10k_Val_000005
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000005
# --Sequence 6/180: GOT-10k_Val_000006
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000006
# --Sequence 7/180: GOT-10k_Val_000007
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000007
# --Sequence 8/180: GOT-10k_Val_000008
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000008
# --Sequence 9/180: GOT-10k_Val_000009
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000009
# ...

# %%
experiment.report(['ResNet18-linear-noncontinuous'])
# Out:
# Evaluating ResNet18-linear-noncontinuous
# Saving success plots to ./reports\GOT-10k\ResNet18-linear-noncontinuous\success_plot.png
# {'ResNet18-linear-noncontinuous': {'overall': {'ao': 0.2333931892085457,
#    'sr': 0.25165913244205057,
#    'speed_fps': 0.5863753275619764,
#    'succ_curve': [0.5275560257766664,
#     0.4705203424064634,
#     0.4551312878715014,
#     0.44363758776570167,
#     0.4345965182264115,
#     0.42680580936808693,
#     0.4189189189189189,
#     0.41083966528806387,
#     0.4043474079061268,
#     0.39886505722804655,
#     0.3933827065499663,
#     0.388910262575743,
#     0.38515918053284603,
#     0.3811195537174185,
#     0.37732038087909975,
#     0.37313648167740693,
#     0.3689044916802924,
#     0.36553813600076945,
#     0.3614023275944984,
#     0.3575550639607579,
#     0.3526978936231605,
#     0.3489468115802635,
#     0.3448590939694143,
#     0.3410599211310955,
#     0.3378859286332596,
#     0.33451957295373663,
# ...

# %%
# ... tracker definition ...

# instantiate a tracker
res_poly_tracker = TestTracker(model_name='resnet18', kernel='poly', device=device, name='ResNet18-poly-noncontinuous', continuous=False)

# setup experiment (validation subset)
experiment = ExperimentGOT10k(
    root_dir='data/GOT-10k',    # GOT-10k's root directory
    subset='val',               # 'train' | 'val' | 'test'
    result_dir='./results',       # where to store tracking results
    report_dir='./reports'        # where to store evaluation reports
)
experiment.run(res_poly_tracker, visualize=False)
# Out:
# Running tracker ResNet18-poly-noncontinuous on GOT-10k...
# --Sequence 1/180: GOT-10k_Val_000001
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-poly-noncontinuous\GOT-10k_Val_000001\GOT-10k_Val_000001_001.txt
# --Sequence 2/180: GOT-10k_Val_000002
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-poly-noncontinuous\GOT-10k_Val_000002\GOT-10k_Val_000002_001.txt
# --Sequence 3/180: GOT-10k_Val_000003
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-poly-noncontinuous\GOT-10k_Val_000003\GOT-10k_Val_000003_001.txt
# --Sequence 4/180: GOT-10k_Val_000004
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-poly-noncontinuous\GOT-10k_Val_000004\GOT-10k_Val_000004_001.txt
# --Sequence 5/180: GOT-10k_Val_000005
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-poly-noncontinuous\GOT-10k_Val_000005\GOT-10k_Val_000005_001.txt
# --Sequence 6/180: GOT-10k_Val_000006
#  Repetition: 1
# ...

# %%
experiment.report(['ResNet18-poly-noncontinuous'])
# Out:
# Evaluating ResNet18-poly-noncontinuous
# Saving success plots to ./reports\GOT-10k\ResNet18-poly-noncontinuous\success_plot.png
# {'ResNet18-poly-noncontinuous': {'overall': {'ao': 0.2360761784367956,
#    'sr': 0.26425892084255076,
#    'speed_fps': 0.6122194287061533,
#    'succ_curve': [0.5137539674906223,
#     0.4612869096854862,
#     0.44402231412907567,
#     0.4333461575454458,
#     0.42435317880157736,
#     0.41656246994325286,
#     0.41007021256131576,
#     0.4034336827931134,
#     0.3973742425699721,
#     0.3927094354140617,
#     0.3879965374627296,
#     0.38453400019236317,
#     0.38063864576320094,
#     0.3777051072424738,
#     0.3739540251995768,
#     0.3697220352024623,
#     0.36597095315956524,
#     0.36279696066172934,
#     0.35938251418678463,
#     0.35673752043858803,
#     0.3540444358949697,
#     0.3515437145330384,
#     0.3489468115802635,
#     0.3464460902183322,
#     0.34332018851591806,
#     0.3408194671539867,
# ...

# %%
# ... tracker definition ...

# instantiate a tracker
res_rbf_tracker = TestTracker(model_name='resnet18', kernel='rbf', device=device, name='ResNet18-rbf-noncontinuous', continuous=False)

# setup experiment (validation subset)
experiment = ExperimentGOT10k(
    root_dir='data/GOT-10k',    # GOT-10k's root directory
    subset='val',               # 'train' | 'val' | 'test'
    result_dir='./results',       # where to store tracking results
    report_dir='./reports'        # where to store evaluation reports
)
experiment.run(res_rbf_tracker, visualize=False)
# Out:
# Running tracker ResNet18-rbf-noncontinuous on GOT-10k...
# --Sequence 1/180: GOT-10k_Val_000001
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-rbf-noncontinuous\GOT-10k_Val_000001\GOT-10k_Val_000001_001.txt
# --Sequence 2/180: GOT-10k_Val_000002
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-rbf-noncontinuous\GOT-10k_Val_000002\GOT-10k_Val_000002_001.txt
# --Sequence 3/180: GOT-10k_Val_000003
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-rbf-noncontinuous\GOT-10k_Val_000003\GOT-10k_Val_000003_001.txt
# --Sequence 4/180: GOT-10k_Val_000004
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-rbf-noncontinuous\GOT-10k_Val_000004\GOT-10k_Val_000004_001.txt
# --Sequence 5/180: GOT-10k_Val_000005
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\ResNet18-rbf-noncontinuous\GOT-10k_Val_000005\GOT-10k_Val_000005_001.txt
# --Sequence 6/180: GOT-10k_Val_000006
#  Repetition: 1
# ...

# %%
experiment.report(['ResNet18-rbf-noncontinuous'])
# Out:
# Evaluating ResNet18-rbf-noncontinuous
# Saving success plots to ./reports\GOT-10k\ResNet18-rbf-noncontinuous\success_plot.png
# {'ResNet18-rbf-noncontinuous': {'overall': {'ao': 0.2640019488606005,
#    'sr': 0.29609502741175336,
#    'speed_fps': 0.5581118411206776,
#    'succ_curve': [0.5653553909781668,
#     0.5043762623833798,
#     0.4899971145522747,
#     0.4795614119457536,
#     0.4707127055881504,
#     0.46287390593440414,
#     0.45642973934788883,
#     0.45046648071559103,
#     0.444551312878715,
#     0.4397903241319611,
#     0.4352216985668943,
#     0.43084543618351445,
#     0.42695008175435223,
#     0.4229104549389247,
#     0.41901510050976243,
#     0.4153121092622872,
#     0.41117630085601614,
#     0.4085793979032413,
#     0.4050687698374531,
#     0.40227950370299126,
#     0.3990574204097336,
#     0.3960757910935847,
#     0.3934307973453881,
#     0.39016062325670864,
#     0.38717899394055977,
#     0.3842935462152544,
#     0.38116764451284024,
# ...

# %%
# ... tracker definition ...

# instantiate a tracker
res_rbf_tracker_con = TestTracker(model_name='resnet18', kernel='rbf', device=device, name='ResNet18-rbf-continuous', continuous=True)

# setup experiment (validation subset)
experiment = ExperimentGOT10k(
    root_dir='data/GOT-10k',    # GOT-10k's root directory
    subset='val',               # 'train' | 'val' | 'test'
    result_dir='./results',       # where to store tracking results
    report_dir='./reports'        # where to store evaluation reports
)
experiment.run(res_rbf_tracker_con, visualize=False)
# Out:
# Running tracker ResNet18-rbf-continuous on GOT-10k...
# --Sequence 1/180: GOT-10k_Val_000001
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000001
# --Sequence 2/180: GOT-10k_Val_000002
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000002
# --Sequence 3/180: GOT-10k_Val_000003
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000003
# --Sequence 4/180: GOT-10k_Val_000004
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000004
# --Sequence 5/180: GOT-10k_Val_000005
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000005
# --Sequence 6/180: GOT-10k_Val_000006
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000006
# --Sequence 7/180: GOT-10k_Val_000007
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000007
# --Sequence 8/180: GOT-10k_Val_000008
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000008
# --Sequence 9/180: GOT-10k_Val_000009
#  Repetition: 1
#   Found results, skipping GOT-10k_Val_000009
# ...

# %%
experiment.report(['ResNet18-rbf-continuous'])
# Out:
# Evaluating ResNet18-rbf-continuous
# Saving success plots to ./reports\GOT-10k\ResNet18-rbf-continuous\success_plot.png
# {'ResNet18-rbf-continuous': {'overall': {'ao': 0.14191113913906214,
#    'sr': 0.11849571991920746,
#    'speed_fps': 0.3543022948119783,
#    'succ_curve': [0.5679522939309416,
#     0.4864864864864865,
#     0.45296720207752234,
#     0.42714244493603926,
#     0.4012695969991344,
#     0.3801577378089834,
#     0.3630855054342599,
#     0.3481292680580937,
#     0.33759738386072907,
#     0.3283158603443301,
#     0.3196114263729922,
#     0.3111474463787631,
#     0.3031162835433298,
#     0.2965278445705492,
#     0.29017985957487735,
#     0.28460132730595367,
#     0.2787342502644994,
#     0.27195344811003175,
#     0.2637780128883332,
#     0.25699721073386556,
#     0.24992786380686738,
#     0.24386842358372607,
#     0.2371357122246802,
#     0.22982591132057323,
#     0.22391074348369722,
#     0.21972684428200442,
#     0.2142444936039242,
# ...

# %%
# ... tracker definition ...

# instantiate a tracker
hog_poly_tracker = TestTracker(model_name='hog', kernel='poly', device=device, name='hog-poly-noncontinuous', continuous=False)

# setup experiment (validation subset)
experiment = ExperimentGOT10k(
    root_dir='data/GOT-10k',    # GOT-10k's root directory
    subset='val',               # 'train' | 'val' | 'test'
    result_dir='./results',       # where to store tracking results
    report_dir='./reports'        # where to store evaluation reports
)
experiment.run(hog_poly_tracker, visualize=False)
# Out:
# Running tracker hog-poly-noncontinuous on GOT-10k...
# --Sequence 1/180: GOT-10k_Val_000001
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-poly-noncontinuous\GOT-10k_Val_000001\GOT-10k_Val_000001_001.txt
# --Sequence 2/180: GOT-10k_Val_000002
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-poly-noncontinuous\GOT-10k_Val_000002\GOT-10k_Val_000002_001.txt
# --Sequence 3/180: GOT-10k_Val_000003
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-poly-noncontinuous\GOT-10k_Val_000003\GOT-10k_Val_000003_001.txt
# --Sequence 4/180: GOT-10k_Val_000004
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-poly-noncontinuous\GOT-10k_Val_000004\GOT-10k_Val_000004_001.txt
# --Sequence 5/180: GOT-10k_Val_000005
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-poly-noncontinuous\GOT-10k_Val_000005\GOT-10k_Val_000005_001.txt
# --Sequence 6/180: GOT-10k_Val_000006
#  Repetition: 1
# ...

# %%
experiment.report(['hog-poly-noncontinuous'])
# Out:
# Evaluating hog-poly-noncontinuous
# Saving success plots to ./reports\GOT-10k\hog-poly-noncontinuous\success_plot.png
# {'hog-poly-noncontinuous': {'overall': {'ao': 0.19629335040619814,
#    'sr': 0.18264884101183035,
#    'speed_fps': 5.796353882228984,
#    'succ_curve': [0.5606905838222564,
#     0.5086082523804943,
#     0.4874963931903434,
#     0.4692699817254977,
#     0.45594883139367126,
#     0.4438780417428104,
#     0.43286524959122824,
#     0.41858228335096664,
#     0.4068481292680581,
#     0.3958353371164759,
#     0.3860248148504376,
#     0.37400211599499855,
#     0.3627488698663076,
#     0.354573434644609,
#     0.346878907377128,
#     0.3390881985188035,
#     0.33288448590939695,
#     0.32802731557179954,
#     0.3231220544387804,
#     0.3185053380782918,
#     0.31331153217274216,
#     0.3095123593344234,
#     0.304462825815139,
#     0.2990285659324805,
#     0.29364239684524385,
#     0.28825622775800713,
#     0.2831105126478792,
# ...

# %%
# ... tracker definition ...

# instantiate a tracker
hog_rbf_tracker = TestTracker(model_name='hog', kernel='rbf', device=device, name='hog-rbf-noncontinuous', continuous=False)

# setup experiment (validation subset)
experiment = ExperimentGOT10k(
    root_dir='data/GOT-10k',    # GOT-10k's root directory
    subset='val',               # 'train' | 'val' | 'test'
    result_dir='./results',       # where to store tracking results
    report_dir='./reports'        # where to store evaluation reports
)
experiment.run(hog_rbf_tracker, visualize=False)
# Out:
# Running tracker hog-rbf-noncontinuous on GOT-10k...
# --Sequence 1/180: GOT-10k_Val_000001
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-rbf-noncontinuous\GOT-10k_Val_000001\GOT-10k_Val_000001_001.txt
# --Sequence 2/180: GOT-10k_Val_000002
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-rbf-noncontinuous\GOT-10k_Val_000002\GOT-10k_Val_000002_001.txt
# --Sequence 3/180: GOT-10k_Val_000003
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-rbf-noncontinuous\GOT-10k_Val_000003\GOT-10k_Val_000003_001.txt
# --Sequence 4/180: GOT-10k_Val_000004
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-rbf-noncontinuous\GOT-10k_Val_000004\GOT-10k_Val_000004_001.txt
# --Sequence 5/180: GOT-10k_Val_000005
#  Repetition: 1
#   Results recorded at ./results\GOT-10k\hog-rbf-noncontinuous\GOT-10k_Val_000005\GOT-10k_Val_000005_001.txt
# --Sequence 6/180: GOT-10k_Val_000006
#  Repetition: 1
# ...

# %%
experiment.report(['hog-rbf-noncontinuous'])
# Out:
# Evaluating hog-rbf-noncontinuous
# Saving success plots to ./reports\GOT-10k\hog-rbf-noncontinuous\success_plot.png
# {'hog-rbf-noncontinuous': {'overall': {'ao': 0.24232493198725688,
#    'sr': 0.23809752813311533,
#    'speed_fps': 5.436719189448294,
#    'succ_curve': [0.5859382514186785,
#     0.5492449745118785,
#     0.5322689237279985,
#     0.5138501490814658,
#     0.5,
#     0.4894200250072136,
#     0.47946523035491007,
#     0.4697508896797153,
#     0.46090218332211214,
#     0.4529191112821006,
#     0.44584976435510243,
#     0.43878041742810425,
#     0.43224006925074543,
#     0.425411176300856,
#     0.4189189189189189,
#     0.4126671155140906,
#     0.4070404924497451,
#     0.400355871886121,
#     0.39371934211791865,
#     0.3877079926901991,
#     0.3811195537174185,
#     0.37510820428969893,
#     0.3690006732711359,
#     0.36342214100221215,
#     0.35750697316533614,
#     0.35168798691930364,
#     0.3462537270366452,
#     0.33990574204097335,
# ...
